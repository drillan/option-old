# %%
# %%HTML
# <link rel="stylesheet" type="text/css" href="custom.css">
# Out:
# <link rel="stylesheet" type="text/css" href="custom.css">

# %%
import numpy as np
import pandas as pd
import fudebako

pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # ホリゾンタルスプレッド

# %% [markdown]
# 1限月|2限月|3限月
# ---|---|---
# 20000|20000|20000
# 20250|20250|20250
# 20500|20500|20500
# 20750|20750|20750
# 21000|21000|21000

# %% [markdown]
# ### バーティカルスプレッド
# 同一限月のオプションの組み合わせ
# * デビッド
# * バタフライ
# * etc

# %% [markdown]
# ### ホリゾンタルスプレッド
# 異なる限月のオプションの組み合わせ
# * カレンダー
# * リバースカレンダー

# %% [markdown]
# ### 戦略
# グリークスの相場観
# * ガンマ/セータ
# * ベガ
#
# ボラティリティの鞘(期近と期先の差)をとりにいく

# %% [markdown]
# ### 時間による影響を整理
#
# 満期までの期間|短い|長い
# ---|---|---
# ベガ|小|大
# ガンマ|大|小

# %% [markdown]
# ### 満期までの期間が短いほど
# 原資産の変動(ガンマ/セータ)の影響が大きい
#
# ### 満期までの期間が長いほど
# ボラティリティ(ベガ)の影響が大きい

# %% [markdown]
# ### カレンダースプレッド
# * 期近をショート・期先をロング(1:1)
# * ガンマ-
# * ベガ+
# * セータ+

# %% [markdown]
# ### リバースカレンダースプレッド
# * 期近をロング・期先をショート(1:1)
# * ガンマ+
# * ベガ-
# * セータ-

# %% [markdown]
# ### カレンダー / リバースカレンダー のデルタ
#
# * ATMで組んで場合にはニュートラル
# * OTMで組んだ場合には期先のデルタの絶対値が大きくなる
#   -> 必要に応じてデルタヘッジ

# %% [markdown]
# ### コンタンゴ(順ザヤ)
# * 期近のボラティリティ > 期先のボラティリティ
#   ※ ATM近辺の行使価格
# * 平時の状態に多い

# %% [markdown]
# ### バックワーデーション(逆ザヤ)
# * 期近のボラティリティ < 期先のボラティリティ
#   ※ ATM近辺の行使価格
# * 相場が波乱になった場合に多い
# * 満期まで1週間以内になった場合に多い
#   この場合にはベガの影響が小さく、ガンマの影響が大きいため、鞘を見る意味はあまりない

# %% [markdown]
# ### ケーススタディ
#
# * カレンダースプレッド
# * リバースカレンダースプレッド
#
# 以降の事例ではカレンダースプレッドの場合の損益やグリークスが表示されるが、リバースカレンダーの場合は符号を逆で考える

# %%
t0 = fudebako.s_df.index[0]
p = fudebako.Portfolio()
p.add(t0, -1, 0, 'P', 21125)
p.add(t0, 1, 1, 'P', 21125)

H, prev1, prev2 = fudebako.draw_dashboard(p, t0)
H
# Out:
#     <table>
#     <tr colspan="2">
#         <td colspan="2">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>qty</th>
#       <th>maturity</th>
#       <th>right</th>
#       <th>a_price</th>
#       <th>c_price</th>
#       <th>pl</th>
#       <th>iv</th>
#       <th>delta</th>
#       <th>gamma</th>
#       <th>vega</th>
#       <th>theta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1.00</td>
#       <td>0</td>
#       <td>P</td>
#       <td>612.50</td>
#       <td>nan</td>
#       <td>0.00</td>
#       <td>0.29</td>
#       <td>0.47</td>
#       <td>-0.25</td>
#       <td>-2149.03</td>
#       <td>13.30</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.00</td>
#       <td>1</td>
#       <td>P</td>
#       <td>897.74</td>
#       <td>nan</td>
#       <td>0.00</td>
#       <td>0.25</td>
#       <td>-0.50</td>
#       <td>0.19</td>
# ...

# %%
t0 = fudebako.s_df.index[1]
p.update(t0)
H, prev1, prev2 = fudebako.draw_dashboard(p, t0, prev1, prev2)
H
# Out:
#     <table>
#     <tr colspan="2">
#         <td colspan="2">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>qty</th>
#       <th>maturity</th>
#       <th>right</th>
#       <th>a_price</th>
#       <th>c_price</th>
#       <th>pl</th>
#       <th>iv</th>
#       <th>delta</th>
#       <th>gamma</th>
#       <th>vega</th>
#       <th>theta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1.00</td>
#       <td>0</td>
#       <td>P</td>
#       <td>612.50</td>
#       <td>551.87</td>
#       <td>60.63</td>
#       <td>0.27</td>
#       <td>0.47</td>
#       <td>-0.28</td>
#       <td>-2103.41</td>
#       <td>12.63</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.00</td>
#       <td>1</td>
#       <td>P</td>
#       <td>897.74</td>
#       <td>841.38</td>
#       <td>-56.35</td>
#       <td>0.23</td>
#       <td>-0.50</td>
#       <td>0.20</td>
# ...

# %%
t0 = fudebako.s_df.index[2]
p.update(t0)
H, prev1, prev2 = fudebako.draw_dashboard(p, t0, prev1, prev2)
H
# Out:
#     <table>
#     <tr colspan="2">
#         <td colspan="2">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>qty</th>
#       <th>maturity</th>
#       <th>right</th>
#       <th>a_price</th>
#       <th>c_price</th>
#       <th>pl</th>
#       <th>iv</th>
#       <th>delta</th>
#       <th>gamma</th>
#       <th>vega</th>
#       <th>theta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1.00</td>
#       <td>0</td>
#       <td>P</td>
#       <td>612.50</td>
#       <td>348.00</td>
#       <td>264.50</td>
#       <td>0.24</td>
#       <td>0.38</td>
#       <td>-0.31</td>
#       <td>-2000.12</td>
#       <td>10.97</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.00</td>
#       <td>1</td>
#       <td>P</td>
#       <td>897.74</td>
#       <td>631.60</td>
#       <td>-266.13</td>
#       <td>0.21</td>
#       <td>-0.45</td>
#       <td>0.22</td>
# ...

# %%
t0 = fudebako.s_df.index[3]
p.update(t0)
H, prev1, prev2 = fudebako.draw_dashboard(p, t0, prev1, prev2)
H
# Out:
#     <table>
#     <tr colspan="2">
#         <td colspan="2">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>qty</th>
#       <th>maturity</th>
#       <th>right</th>
#       <th>a_price</th>
#       <th>c_price</th>
#       <th>pl</th>
#       <th>iv</th>
#       <th>delta</th>
#       <th>gamma</th>
#       <th>vega</th>
#       <th>theta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1.00</td>
#       <td>0</td>
#       <td>P</td>
#       <td>612.50</td>
#       <td>229.51</td>
#       <td>382.99</td>
#       <td>0.23</td>
#       <td>0.30</td>
#       <td>-0.29</td>
#       <td>-1787.85</td>
#       <td>9.94</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.00</td>
#       <td>1</td>
#       <td>P</td>
#       <td>897.74</td>
#       <td>486.85</td>
#       <td>-410.89</td>
#       <td>0.21</td>
#       <td>-0.38</td>
#       <td>0.22</td>
# ...

# %%
t0 = fudebako.s_df.index[4]
p.update(t0)
H, prev1, prev2 = fudebako.draw_dashboard(p, t0, prev1, prev2)
H
# Out:
#     <table>
#     <tr colspan="2">
#         <td colspan="2">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>qty</th>
#       <th>maturity</th>
#       <th>right</th>
#       <th>a_price</th>
#       <th>c_price</th>
#       <th>pl</th>
#       <th>iv</th>
#       <th>delta</th>
#       <th>gamma</th>
#       <th>vega</th>
#       <th>theta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1.00</td>
#       <td>0</td>
#       <td>P</td>
#       <td>612.50</td>
#       <td>126.42</td>
#       <td>486.08</td>
#       <td>0.24</td>
#       <td>0.19</td>
#       <td>-0.23</td>
#       <td>-1322.99</td>
#       <td>9.00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.00</td>
#       <td>1</td>
#       <td>P</td>
#       <td>897.74</td>
#       <td>343.18</td>
#       <td>-554.55</td>
#       <td>0.21</td>
#       <td>-0.30</td>
#       <td>0.20</td>
# ...

# %%
t0 = fudebako.s_df.index[5]
p.update(t0)
H, prev1, prev2 = fudebako.draw_dashboard(p, t0, prev1, prev2)
H
# Out:
#     <table>
#     <tr colspan="2">
#         <td colspan="2">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>qty</th>
#       <th>maturity</th>
#       <th>right</th>
#       <th>a_price</th>
#       <th>c_price</th>
#       <th>pl</th>
#       <th>iv</th>
#       <th>delta</th>
#       <th>gamma</th>
#       <th>vega</th>
#       <th>theta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1.00</td>
#       <td>0</td>
#       <td>P</td>
#       <td>612.50</td>
#       <td>172.47</td>
#       <td>440.03</td>
#       <td>0.25</td>
#       <td>0.24</td>
#       <td>-0.26</td>
#       <td>-1455.66</td>
#       <td>11.05</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.00</td>
#       <td>1</td>
#       <td>P</td>
#       <td>897.74</td>
#       <td>407.14</td>
#       <td>-490.59</td>
#       <td>0.21</td>
#       <td>-0.34</td>
#       <td>0.21</td>
# ...

# %% [markdown]
# ### ダイアゴナルスプレッド
# * 異なる限月・権利行使価格のオプションをロング・ショート
# * 通常は期先のほうが期近よりもOTM側になる
# * デルタがニュートラルな権利行使価格同士で組むことが多い
# * OTMになるため、ATMのカレンダーよりたくさん組むことが多い
#   グリークスの変動が大きくなる

# %% [markdown]
# ### ケーススタディ
#
# * ダイアゴナル・カレンダースプレッド
# * ダイアゴナル・リバースカレンダースプレッド
#
# 以降の事例ではカレンダースプレッドの場合の損益やグリークスが表示されるが、リバースカレンダーの場合は符号を逆で考える
#
# ※ ガンマは1000倍、セータは1/365倍表示

# %%
t0 = fudebako.s_df.index[0]
p = fudebako.Portfolio()
p.add(t0, -1, 0, 'C', 22000)
p.add(t0, 1, 1, 'C', 22250)
H, prev1, prev2 = fudebako.draw_dashboard(p, t0)
H
# Out:
#     <table>
#     <tr colspan="2">
#         <td colspan="2">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>qty</th>
#       <th>maturity</th>
#       <th>right</th>
#       <th>a_price</th>
#       <th>c_price</th>
#       <th>pl</th>
#       <th>iv</th>
#       <th>delta</th>
#       <th>gamma</th>
#       <th>vega</th>
#       <th>theta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1.00</td>
#       <td>0</td>
#       <td>C</td>
#       <td>245.21</td>
#       <td>nan</td>
#       <td>0.00</td>
#       <td>0.26</td>
#       <td>-0.29</td>
#       <td>-0.25</td>
#       <td>-1848.30</td>
#       <td>10.07</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.00</td>
#       <td>1</td>
#       <td>C</td>
#       <td>304.85</td>
#       <td>nan</td>
#       <td>0.00</td>
#       <td>0.22</td>
#       <td>0.28</td>
#       <td>0.18</td>
# ...

# %%
t0 = fudebako.s_df.index[1]
p.update(t0)
H, prev1, prev2 = fudebako.draw_dashboard(p, t0, prev1, prev2)
H
# Out:
#     <table>
#     <tr colspan="2">
#         <td colspan="2">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>qty</th>
#       <th>maturity</th>
#       <th>right</th>
#       <th>a_price</th>
#       <th>c_price</th>
#       <th>pl</th>
#       <th>iv</th>
#       <th>delta</th>
#       <th>gamma</th>
#       <th>vega</th>
#       <th>theta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1.00</td>
#       <td>0</td>
#       <td>C</td>
#       <td>245.21</td>
#       <td>195.00</td>
#       <td>50.21</td>
#       <td>0.23</td>
#       <td>-0.27</td>
#       <td>-0.26</td>
#       <td>-1734.86</td>
#       <td>8.96</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.00</td>
#       <td>1</td>
#       <td>C</td>
#       <td>304.85</td>
#       <td>257.14</td>
#       <td>-47.70</td>
#       <td>0.21</td>
#       <td>0.26</td>
#       <td>0.19</td>
# ...

# %%
t0 = fudebako.s_df.index[2]
p.update(t0)
H, prev1, prev2 = fudebako.draw_dashboard(p, t0, prev1, prev2)
H
# Out:
#     <table>
#     <tr colspan="2">
#         <td colspan="2">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>qty</th>
#       <th>maturity</th>
#       <th>right</th>
#       <th>a_price</th>
#       <th>c_price</th>
#       <th>pl</th>
#       <th>iv</th>
#       <th>delta</th>
#       <th>gamma</th>
#       <th>vega</th>
#       <th>theta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1.00</td>
#       <td>0</td>
#       <td>C</td>
#       <td>245.21</td>
#       <td>215.52</td>
#       <td>29.69</td>
#       <td>0.21</td>
#       <td>-0.32</td>
#       <td>-0.33</td>
#       <td>-1865.71</td>
#       <td>8.84</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.00</td>
#       <td>1</td>
#       <td>C</td>
#       <td>304.85</td>
#       <td>278.61</td>
#       <td>-26.24</td>
#       <td>0.19</td>
#       <td>0.29</td>
#       <td>0.21</td>
# ...

# %%
t0 = fudebako.s_df.index[3]
p.update(t0)
H, prev1, prev2 = fudebako.draw_dashboard(p, t0, prev1, prev2)
H
# Out:
#     <table>
#     <tr colspan="2">
#         <td colspan="2">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>qty</th>
#       <th>maturity</th>
#       <th>right</th>
#       <th>a_price</th>
#       <th>c_price</th>
#       <th>pl</th>
#       <th>iv</th>
#       <th>delta</th>
#       <th>gamma</th>
#       <th>vega</th>
#       <th>theta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1.00</td>
#       <td>0</td>
#       <td>C</td>
#       <td>245.21</td>
#       <td>281.20</td>
#       <td>-35.99</td>
#       <td>0.19</td>
#       <td>-0.40</td>
#       <td>-0.39</td>
#       <td>-2003.87</td>
#       <td>9.39</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.00</td>
#       <td>1</td>
#       <td>C</td>
#       <td>304.85</td>
#       <td>330.29</td>
#       <td>25.45</td>
#       <td>0.18</td>
#       <td>0.34</td>
#       <td>0.24</td>
# ...

# %%
t0 = fudebako.s_df.index[4]
p.update(t0)
H, prev1, prev2 = fudebako.draw_dashboard(p, t0, prev1, prev2)
H
# Out:
#     <table>
#     <tr colspan="2">
#         <td colspan="2">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>qty</th>
#       <th>maturity</th>
#       <th>right</th>
#       <th>a_price</th>
#       <th>c_price</th>
#       <th>pl</th>
#       <th>iv</th>
#       <th>delta</th>
#       <th>gamma</th>
#       <th>vega</th>
#       <th>theta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1.00</td>
#       <td>0</td>
#       <td>C</td>
#       <td>245.21</td>
#       <td>441.97</td>
#       <td>-196.76</td>
#       <td>0.20</td>
#       <td>-0.55</td>
#       <td>-0.41</td>
#       <td>-1927.74</td>
#       <td>10.89</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.00</td>
#       <td>1</td>
#       <td>C</td>
#       <td>304.85</td>
#       <td>461.67</td>
#       <td>156.82</td>
#       <td>0.18</td>
#       <td>0.43</td>
#       <td>0.26</td>
# ...

# %%
t0 = fudebako.s_df.index[5]
p.update(t0)
H, prev1, prev2 = fudebako.draw_dashboard(p, t0, prev1, prev2)
H
# Out:
#     <table>
#     <tr colspan="2">
#         <td colspan="2">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>qty</th>
#       <th>maturity</th>
#       <th>right</th>
#       <th>a_price</th>
#       <th>c_price</th>
#       <th>pl</th>
#       <th>iv</th>
#       <th>delta</th>
#       <th>gamma</th>
#       <th>vega</th>
#       <th>theta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1.00</td>
#       <td>0</td>
#       <td>C</td>
#       <td>245.21</td>
#       <td>349.00</td>
#       <td>-103.79</td>
#       <td>0.21</td>
#       <td>-0.48</td>
#       <td>-0.41</td>
#       <td>-1870.40</td>
#       <td>11.49</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.00</td>
#       <td>1</td>
#       <td>C</td>
#       <td>304.85</td>
#       <td>390.94</td>
#       <td>86.09</td>
#       <td>0.18</td>
#       <td>0.39</td>
#       <td>0.26</td>
# ...
